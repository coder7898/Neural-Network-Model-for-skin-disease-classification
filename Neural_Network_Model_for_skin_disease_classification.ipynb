# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Neural Network Model for skin diseases classification/Skin disease/hmnist_28_28_L.csv')

# %%
data
# Out:
#        pixel0000  pixel0001  pixel0002  ...  pixel0782  pixel0783  label
# 0            169        171        170  ...        159        165      2
# 1             19         57        105  ...         18         18      2
# 2            155        163        161  ...        136        115      2
# 3             25         71        116  ...         16         16      2
# 4            129        162        181  ...        147         88      2
# ...          ...        ...        ...  ...        ...        ...    ...
# 10010        172        171        173  ...        192        192      0
# 10011          2         34        108  ...         23          3      0
# 10012        122        154        162  ...        164        156      0
# 10013        137        143        141  ...        166        170      0
# 10014        149        157        157  ...        146        148      6
#
# [10015 rows x 785 columns]

# %%
np.sqrt(784)
# Out:
# 28.0

# %% [markdown]
# # Presrocessing

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
y = data['label'].copy()
X = data.drop('label', axis=1).copy()

# %%
y.value_counts()
# Out:
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: label, dtype: int64

# %%
label_mapping = {
    0: 'nv',
    1: 'mel',
    2: 'bkl',
    3: 'bcc',
    4: 'akiec',
    5: 'vasc',
    6: 'df'
}

# %% [markdown]
# #Rescaling

# %%
X = X / 255

X
# Out:
#        pixel0000  pixel0001  pixel0002  ...  pixel0781  pixel0782  pixel0783
# 0       0.662745   0.670588   0.666667  ...   0.549020   0.623529   0.647059
# 1       0.074510   0.223529   0.411765  ...   0.184314   0.070588   0.070588
# 2       0.607843   0.639216   0.631373  ...   0.552941   0.533333   0.450980
# 3       0.098039   0.278431   0.454902  ...   0.125490   0.062745   0.062745
# 4       0.505882   0.635294   0.709804  ...   0.709804   0.576471   0.345098
# ...          ...        ...        ...  ...        ...        ...        ...
# 10010   0.674510   0.670588   0.678431  ...   0.752941   0.752941   0.752941
# 10011   0.007843   0.133333   0.423529  ...   0.325490   0.090196   0.011765
# 10012   0.478431   0.603922   0.635294  ...   0.733333   0.643137   0.611765
# 10013   0.537255   0.560784   0.552941  ...   0.662745   0.650980   0.666667
# 10014   0.584314   0.615686   0.615686  ...   0.403922   0.572549   0.580392
#
# [10015 rows x 784 columns]

# %% [markdown]
# #Reshaping

# %%
X = np.array(X)
print(X.shape)
# Out:
# (10015, 784)

# %%
X = X.reshape(-1, 28, 28, 1)
print(X.shape)
# Out:
# (10015, 28, 28, 1)

# %% [markdown]
# # Visualizing

# %%
sample_data = pd.Series(list(zip(X, y))).sample(15)

sample_X = np.stack(np.array(sample_data.apply(lambda x: x[0])))
sample_y = np.array(sample_data.apply(lambda x: x[1]))

# %%
plt.figure(figsize=(12, 12))

for i in range(15):
    plt.subplot(5, 5, i + 1)
    plt.imshow(np.squeeze(sample_X[i]))
    img_label = label_mapping[sample_y[i]]
    plt.title(img_label)
    plt.axis("off")

plt.show()

# %% [markdown]
# # Splitting for train-test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

# %% [markdown]
# #Modeling

# %%
inputs = tf.keras.Input(shape=(28, 28, 1), name='input')

conv1 = tf.keras.layers.Conv2D(filters=16, kernel_size=3, name='conv1')(inputs)
maxpool1 = tf.keras.layers.MaxPooling2D(name='maxpool1')(conv1)

conv2 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, name='conv2')(maxpool1)
maxpool2 = tf.keras.layers.MaxPooling2D(name='maxpool2')(conv2)

conv3 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, name='conv3')(maxpool2)
maxpool3 = tf.keras.layers.MaxPooling2D(name='maxpool3')(conv3)

avgpool = tf.keras.layers.GlobalAveragePooling2D(name='avgpool')(maxpool3)

outputs = tf.keras.layers.Dense(7, activation='softmax', name='output')(avgpool)


model = tf.keras.Model(inputs=inputs, outputs=outputs)

print(model.summary())
tf.keras.utils.plot_model(model)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 26, 26, 16)        160
# _________________________________________________________________
# maxpool1 (MaxPooling2D)      (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 11, 11, 32)        4640
# _________________________________________________________________
# maxpool2 (MaxPooling2D)      (None, 5, 5, 32)          0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 3, 3, 64)          18496
# _________________________________________________________________
# maxpool3 (MaxPooling2D)      (None, 1, 1, 64)          0
# _________________________________________________________________
# avgpool (GlobalAveragePoolin (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 7)                 455
# =================================================================
# Total params: 23,751
# Trainable params: 23,751
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


batch_size = 32
epochs = 50

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 4s 19ms/step - loss: 1.1514 - accuracy: 0.6724 - val_loss: 1.1015 - val_accuracy: 0.6583
# Epoch 2/50
# 176/176 [==============================] - 3s 17ms/step - loss: 1.0262 - accuracy: 0.6797 - val_loss: 1.0165 - val_accuracy: 0.6576
# Epoch 3/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.9673 - accuracy: 0.6769 - val_loss: 0.9891 - val_accuracy: 0.6619
# Epoch 4/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.9371 - accuracy: 0.6830 - val_loss: 0.9549 - val_accuracy: 0.6641
# Epoch 5/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.9146 - accuracy: 0.6894 - val_loss: 0.9543 - val_accuracy: 0.6698
# Epoch 6/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.9045 - accuracy: 0.6920 - val_loss: 0.9332 - val_accuracy: 0.6655
# Epoch 7/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.8963 - accuracy: 0.6935 - val_loss: 0.9388 - val_accuracy: 0.6690
# Epoch 8/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.8760 - accuracy: 0.6979 - val_loss: 0.9275 - val_accuracy: 0.6755
# Epoch 9/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.8783 - accuracy: 0.6995 - val_loss: 0.9243 - val_accuracy: 0.6740
# Epoch 10/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.8658 - accuracy: 0.7036 - val_loss: 1.0299 - val_accuracy: 0.6719
# Epoch 11/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.8597 - accuracy: 0.7054 - val_loss: 0.9353 - val_accuracy: 0.6797
# Epoch 12/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.8461 - accuracy: 0.7074 - val_loss: 0.9133 - val_accuracy: 0.6769
# Epoch 13/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.8364 - accuracy: 0.7124 - val_loss: 0.9258 - val_accuracy: 0.6698
# Epoch 14/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.8348 - accuracy: 0.7108 - val_loss: 0.9050 - val_accuracy: 0.6776
# Epoch 15/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.8194 - accuracy: 0.7158 - val_loss: 0.9025 - val_accuracy: 0.6805
# Epoch 16/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.8145 - accuracy: 0.7188 - val_loss: 0.9014 - val_accuracy: 0.6812
# Epoch 17/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.8103 - accuracy: 0.7200 - val_loss: 0.9183 - val_accuracy: 0.6683
# Epoch 18/50
# 176/176 [==============================] - 3s 17ms/step - loss: 0.7998 - accuracy: 0.7249 - val_loss: 0.9131 - val_accuracy: 0.6797
# Epoch 19/50
# 176/176 [==============================] - 3s 18ms/step - loss: 0.7897 - accuracy: 0.7281 - val_loss: 0.9438 - val_accuracy: 0.6797

# %% [markdown]
# #Results

# %%
model_acc = model.evaluate(X_test, y_test, verbose=0)[1]

print("Test Accuracy: {:.3f}%".format(model_acc * 100))
# Out:
# Test Accuracy: 69.185%

# %%
y_true = np.array(y_test)

y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))

# %%
y_true
# Out:
# array([0, 4, 4, ..., 4, 4, 4])

# %%
y_pred
# Out:
# array([4, 4, 4, ..., 4, 4, 4])

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred)
clr = classification_report(y_true, y_pred, target_names=label_mapping.values())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cbar=False, cmap='Blues')

plt.xticks(np.arange(7) + 0.5, label_mapping.values())
plt.xlabel("Predicted")

plt.yticks(np.arange(7) + 0.5, label_mapping.values())
plt.ylabel("Actual")

plt.title("Confusion Matrix")

plt.show()

# %%
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#           nv       0.36      0.13      0.19        94
#          mel       0.34      0.26      0.30       154
#          bkl       0.45      0.18      0.26       328
#          bcc       0.00      0.00      0.00        37
#        akiec       0.75      0.95      0.84      1990
#         vasc       0.00      0.00      0.00        49
#           df       0.40      0.22      0.29       353
#
#     accuracy                           0.69      3005
#    macro avg       0.33      0.25      0.27      3005
# weighted avg       0.62      0.69      0.64      3005
